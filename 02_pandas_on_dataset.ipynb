# %% [markdown]
# # **ALASKA Population Analysis**

# %% [markdown]
# **Author Name:** Syed Abdul Qadir Gilani\
# **Email:** syedabdulqadirgilani40@gmail.com

# %% [markdown]
# The Data was collected from the following [link](https://github.com/JoshData/historical-state-population-csv/blob/primary/historical_state_population_by_year.csv):
#
# **Years of Data:**
#
# 1900
# 1910
# 1920
# 1930
# 1940
# 1950
# 1960
# 1970
# 1980
# 1990
# 2000
# 2010
# 2020

# %% [markdown]
# ## *The Dataset collected from the source has the following description:*
# `Description`
# This dataset contains demographic information from the U.S. Census conducted from 1900 to 2020 📊. It provides detailed population data at the state level within the United States, including the District of Columbia. The dataset includes information on population figures for each decade, allowing for analysis of trends over time 📈.
#
# `Features`
# - **State**: The U.S. states and the District of Columbia where the census data was collected.
# - **Year**: The year of the census data, ranging from 1900 to 2020.
# - **Population**: The total population of each state for the given year.
#
# `Data Source`
# The data in this dataset was collected from official U.S. Census reports and may include data from various government sources. It is essential to provide proper attribution and reference the original sources when using this dataset for analysis or research 📚.
#
# `Data Usage`
# Researchers and analysts can use this dataset to explore demographic trends, population growth, and more within the United States at the state level. Ensure compliance with ethical and legal guidelines when using this data for research or public sharing 🔍.
#
# Please note that this description is a template, and you should adapt it based on the actual data sources and specific details of your dataset when creating it for Kaggle or any other platform.

# %% [markdown]
# ## Purpose of this analysis:
#
# We will fill this at the end or during the process

# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Improt the dataset
df = pd.read_csv('https://raw.githubusercontent.com/JoshData/historical-state-population-csv/refs/heads/primary/historical_state_population_by_year.csv')

# %% [markdown]
# # 1. Composition

# %%
# Explore the data (Compsotion)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6019 entries, 0 to 6018
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AK      6019 non-null   object
#  1   1950    6019 non-null   int64
#  2   135000  6019 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 141.2+ KB

# %%
df.head()
# Out:
#    AK  1950  135000
# 0  AK  1951  158000
# 1  AK  1952  189000
# 2  AK  1953  205000
# 3  AK  1954  215000
# 4  AK  1955  222000

# %%
# max column priniting option 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    AK  1950  135000
# 0  AK  1951  158000
# 1  AK  1952  189000
# 2  AK  1953  205000
# 3  AK  1954  215000
# 4  AK  1955  222000

# %%
# lets see all column names at once
df.columns
# Out:
# Index(['AK', '1950', '135000'], dtype='object')

# %%
# let's have a look on dtypes
df.dtypes # we already have seen this in info column as well
# Out:
# AK        object
# 1950       int64
# 135000     int64
# dtype: object

# %%
# summary Statistics
df.describe().T
# Out:
#          count          mean           std      min       25%        50%  \
# 1950    6019.0  1.960083e+03  3.458444e+01   1900.0    1930.0     1960.0
# 135000  6019.0  3.726599e+06  4.554059e+06  43000.0  902488.5  2359000.0
#
#               75%         max
# 1950       1990.0      2019.0
# 135000  4542766.0  39512223.0

# %%
# how many are the missing value
df.isnull().sum()
# Out:
# AK        0
# 1950      0
# 135000    0
# dtype: int64

# %%
# box plot
sns.histplot(df, x='1950')
# Out:
# <Axes: xlabel='1950', ylabel='Count'>

# %%
sns.boxplot(df, y="135000")
# Out:
# <Axes: ylabel='135000'>

# %%
df.columns
# Out:
# Index(['AK', '1950', '135000'], dtype='object')

# %%
sns.boxplot(df, y='135000', x='1950')
# Out:
# <Axes: xlabel='1950', ylabel='135000'>

# %%
# it is very hard to plot, therefore, we will use groupby function to make tabulated data output
df['AK'].nunique()
# Out:
# 51

# %%
len(df)
# Out:
# 6019

# %%
df['135000'].nunique()
# Out:
# 4994

# %%
df.groupby(['AK']).size().sort_values()
# Out:
# AK
# AK     69
# HI     70
# AR    120
# AL    120
# CA    120
# CO    120
# CT    120
# AZ    120
# DC    120
# DE    120
# FL    120
# GA    120
# IA    120
# ID    120
# IL    120
# IN    120
# KS    120
# KY    120
# LA    120
# MA    120
# MD    120
# ME    120
# MI    120
# MN    120
# MO    120
# MS    120
# MT    120
# NC    120
# ND    120
# NE    120
# NH    120
# NJ    120
# NM    120
# NV    120
# NY    120
# OH    120
# OK    120
# OR    120
# PA    120
# RI    120
# SC    120
# SD    120
# TN    120
# TX    120
# UT    120
# VA    120
# VT    120
# WA    120
# WI    120
# WV    120
# WY    120
# dtype: int64

# %%
df.head()
# Out:
#    AK  1950  135000
# 0  AK  1951  158000
# 1  AK  1952  189000
# 2  AK  1953  205000
# 3  AK  1954  215000
# 4  AK  1955  222000

# %%
df.groupby(['AK','135000'])['1950'].mean()
# Out:
# AK  135000
# AK  158000      1951.000000
#     189000      1952.000000
#     205000      1953.000000
#     215000      1954.000000
#     222000      1955.000000
#     224000      1957.666667
#     229000      1960.000000
#     231000      1957.000000
#     238000      1961.000000
#     246000      1962.000000
#     256000      1963.000000
#     263000      1964.000000
#     271000      1965.500000
#     278000      1967.000000
#     285000      1968.000000
#     296000      1969.000000
#     302583      1970.000000
#     315510      1971.000000
#     324464      1972.000000
#     330543      1973.000000
#     341063      1974.000000
#     376170      1975.000000
#     400969      1976.000000
#     402753      1979.000000
#     403436      1977.000000
#     404766      1978.000000
#     405315      1980.000000
#     418491      1981.000000
#     449606      1982.000000
#     488417      1983.000000
#     513702      1984.000000
#     532495      1985.000000
# ...

# %%
df.groupby(['AK','1950'])['135000'].mean()
# Out:
# AK  1950
# AK  1951      158000.0
#     1952      189000.0
#     1953      205000.0
#     1954      215000.0
#     1955      222000.0
#     1956      224000.0
#     1957      231000.0
#     1958      224000.0
#     1959      224000.0
#     1960      229000.0
#     1961      238000.0
#     1962      246000.0
#     1963      256000.0
#     1964      263000.0
#     1965      271000.0
#     1966      271000.0
#     1967      278000.0
#     1968      285000.0
#     1969      296000.0
#     1970      302583.0
#     1971      315510.0
#     1972      324464.0
#     1973      330543.0
#     1974      341063.0
#     1975      376170.0
#     1976      400969.0
#     1977      403436.0
#     1978      404766.0
#     1979      402753.0
#     1980      405315.0
#     1981      418491.0
#     1982      449606.0
#     1983      488417.0
#     1984      513702.0
#     1985      532495.0
#     1986      544268.0
#     1987      539309.0
#     1988      541983.0
#     1989      547159.0
# ...

# %%
df.describe().T
# Out:
#          count          mean           std      min       25%        50%  \
# 1950    6019.0  1.960083e+03  3.458444e+01   1900.0    1930.0     1960.0
# 135000  6019.0  3.726599e+06  4.554059e+06  43000.0  902488.5  2359000.0
#
#               75%         max
# 1950       1990.0      2019.0
# 135000  4542766.0  39512223.0

# %%
df['1950'].sum()
# Out:
# np.int64(11797740)
